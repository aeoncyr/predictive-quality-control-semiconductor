# %%
import pickle
import joblib
import json
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, make_scorer, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
# Load data
with open('../dataset/secom_data_smoted.pkl', 'rb') as file:
    secom_data = pickle.load(file)
with open('../dataset/secom_pca_optimal.pkl', 'rb') as file:
    secom_data_pca = pickle.load(file)
with open('../dataset/secom_labels_smoted.pkl', 'rb') as file:
    secom_labels = pickle.load(file).squeeze()

print(secom_data.head())
print(secom_data_pca.head())
print(secom_labels)
# Out:
#        0        1          2          3       4      5         6       7    \
# 0  3031.79  2479.69  2186.9889   949.2201  1.2981  100.0  103.3322  0.1219
# 1  3049.97  2441.12  2263.3222  1383.8334  2.3986  100.0   85.1778  0.1196
# 2  2870.76  2583.56  2192.1889  1435.9611  2.3870  100.0  107.3989  0.1229
# 3  2996.90  2448.07  2162.7556  1041.1557  0.8479  100.0  107.2622  0.1221
# 4  2943.83  2445.17  2236.0667  1680.1825  1.4834  100.0   98.6889  0.1221
#
#       8       9    ...       580         581     582     583     584     585  \
# 0  1.4636  0.0009  ...  0.010500   70.061800  0.5035  0.0085  0.0024  1.6818
# 1  1.3792  0.0054  ...  0.003300   39.552800  0.5053  0.0159  0.0038  3.1456
# 2  1.4719 -0.0003  ...  0.006300  193.828600  0.5010  0.0127  0.0037  2.5344
# 3  1.4446 -0.0016  ...  0.005372   98.442837  0.5039  0.0169  0.0046  3.3497
# 4  1.4674  0.0161  ...  0.003900   49.945400  0.5001  0.0190  0.0043  3.7940
#
#       586     587     588       589
# 0  0.0484  0.0339  0.0105   70.0618
# 1  0.0262  0.0104  0.0033   39.5528
# 2  0.0111  0.0215  0.0063  193.8286
# 3  0.0270  0.0162  0.0051   59.9813
# 4  0.0263  0.0131  0.0039   49.9454
#
# [5 rows x 590 columns]
#        pca0      pca1      pca2      pca3      pca4      pca5      pca6  \
# 0 -0.745919 -0.107453  3.591644 -2.265536 -1.078267  0.432353  3.203899
# 1 -0.216757 -3.260718 -4.588246  3.149332 -2.764609  0.952748 -1.532326
# 2  0.074150 -3.289006 -1.796025  2.121192  5.671939 -3.015517 -4.380292
# 3 -2.068737 -1.618181  0.562071 -2.430329 -1.997399  1.386938 -1.210674
# 4  0.318059 -0.548636  2.378547 -2.263819  4.148558 -0.935857  0.080347
#
#        pca7      pca8      pca9  ...    pca148    pca149    pca150    pca151  \
# 0 -1.459073  0.586332 -0.128462  ...  0.617620 -0.893545  0.453805  1.050086
# 1 -1.837786  3.542802  3.169517  ...  0.201125 -0.469154  0.028369  1.808737
# 2 -2.632518 -1.438263  2.184055  ...  0.803649 -0.285608 -0.119930 -1.631770
# 3 -2.325835  1.248291  0.108320  ...  0.663649  0.208386  0.247117  0.067094
# 4  0.415719 -1.885002 -3.042241  ... -1.337143 -0.726921  0.613417  1.001962
#
#      pca152    pca153    pca154    pca155    pca156    pca157
# 0  0.414322 -1.860811  0.009957 -1.160999  1.234229 -1.351209
# 1 -0.702736  0.177183  0.622967  0.430252 -0.993276 -2.071037
# 2 -0.202045  1.095772  0.525432  0.132978  0.597783 -0.650503
# 3 -0.132623  0.338343  0.149476  1.010723 -0.379310  0.022590
# 4  1.578051  0.214746 -0.678007 -0.476125  0.864945 -0.214531
#
# [5 rows x 158 columns]
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2921    0
# 2922    0
# 2923    0
# 2924    0
# 2925    0
# Name: Label, Length: 2926, dtype: int64

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(secom_data, secom_labels, test_size=0.3, random_state=42)

# Train-test split PCA
X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(secom_data_pca, secom_labels, test_size=0.3, random_state=42)

# %%
## Model definition

# Define Base model
base_sgd_log = SGDClassifier(loss='log_loss', max_iter=1000, random_state=42)

# Wrap the logistic regression model with Bagging
bagging_sgd_log = BaggingClassifier(estimator=base_sgd_log, random_state=42)

# Use StratifiedKFold to maintain the proportion of classes in each fold
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Change evaluation metrics to F1-score
f1_scorer = make_scorer(f1_score, pos_label=0)

# Perform Grid search for best parameters

# Define grid parameters
param_grid = {
    'estimator__alpha': [0.0001, 0.001, 0.01],  # Regularization strength
    'estimator__penalty': ['l2', 'l1', 'elasticnet'],  # Regularization type
    'estimator__learning_rate': ['constant', 'optimal', 'invscaling', 'adaptive'],
    'estimator__eta0': [0.01, 0.1, 1.0]  # Initial learning rate
}

# %%
# Train using the smoted data first

# Perform grid search with cross-validation
grid_search = GridSearchCV(estimator=bagging_sgd_log, param_grid=param_grid, cv=stratified_kfold, scoring=f1_scorer, verbose=2)
grid_search.fit(X_train, y_train)

# Use the best found model
best_sgd_model = grid_search.best_estimator_

# Best parameters found
print(f"Best parameters found: {grid_search.best_params_}")

# Predict and evaluate the model
sgd_pred_best = best_sgd_model.predict(X_test)

print("Best Logistic Regression Performance:")
print(f"Accuracy: {accuracy_score(y_test, sgd_pred_best):.4f}")
print(f"Precision: {precision_score(y_test, sgd_pred_best, pos_label=1):.4f}")
print(f"Recall: {recall_score(y_test, sgd_pred_best, pos_label=1):.4f}")
print(f"F1-Score: {f1_score(y_test, sgd_pred_best, pos_label=1):.4f}")

conf_matrix = confusion_matrix(y_test, sgd_pred_best)
f1_score_smoted = f1_score(y_test, sgd_pred_best)
report = classification_report(y_test, sgd_pred_best)

print("Confusion Matrix:")
print(conf_matrix)

print("\nClassification Report:")
print(report)

print("\n F1 Score:")
print(f1_score_smoted)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   4.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   4.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   4.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   4.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   5.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   4.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   4.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   4.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   4.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   4.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   5.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   5.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   5.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   6.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   5.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   4.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   7.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   5.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   6.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   6.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   6.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   4.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   4.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   4.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   4.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   4.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   5.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   4.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   5.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   4.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   5.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   1.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   1.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   1.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   3.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   6.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   6.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   6.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   5.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   7.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   7.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   7.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   2.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   3.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   3.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.5s
# ...
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   2.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   2.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   6.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   3.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   5.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   5.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   4.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   7.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   6.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   6.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   6.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   6.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   6.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   3.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   4.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   3.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   4.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   2.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   2.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   3.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   5.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   6.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   6.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   6.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   7.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   7.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   7.7s
# Best parameters found: {'estimator__alpha': 0.01, 'estimator__eta0': 0.1, 'estimator__learning_rate': 'invscaling', 'estimator__penalty': 'l1'}
# Best Logistic Regression Performance:
# Accuracy: 0.9670
# Precision: 0.9792
# Recall: 0.9549
# F1-Score: 0.9669
# Confusion Matrix:
# [[426   9]
#  [ 20 423]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       435
#            1       0.98      0.95      0.97       443
#
#     accuracy                           0.97       878
#    macro avg       0.97      0.97      0.97       878
# weighted avg       0.97      0.97      0.97       878
#
#
#  F1 Score:
# 0.9668571428571429

# %%
# Now train using the PCA data

# Perform grid search with cross-validation
grid_search_pca = GridSearchCV(estimator=bagging_sgd_log, param_grid=param_grid, cv=stratified_kfold, scoring=f1_scorer, verbose=2)
grid_search_pca.fit(X_train_pca, y_train_pca)

# Best parameters found
print(f"Best parameters found: {grid_search_pca.best_params_}")

# Use the best found model
best_sgd_model_pca = grid_search_pca.best_estimator_

# Predict and evaluate the model
sgd_pred_best_pca = best_sgd_model_pca.predict(X_test_pca)
print("Best Logistic Regression Performance:")
print(f"Accuracy: {accuracy_score(y_test_pca, sgd_pred_best_pca):.4f}")
print(f"Precision: {precision_score(y_test_pca, sgd_pred_best_pca, pos_label=1):.4f}")
print(f"Recall: {recall_score(y_test_pca, sgd_pred_best_pca, pos_label=1):.4f}")
print(f"F1-Score: {f1_score(y_test_pca, sgd_pred_best_pca, pos_label=1):.4f}")

conf_matrix_pca = confusion_matrix(y_test_pca, sgd_pred_best_pca)
f1_score_pca = f1_score(y_test_pca, sgd_pred_best_pca)
report_pca = classification_report(y_test_pca, sgd_pred_best_pca)

print("Confusion Matrix:")
print(conf_matrix_pca)

print("\nClassification Report:")
print(report_pca)

print("\n F1 Score:")
print(f1_score_pca)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   1.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.9s
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   1.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   1.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   1.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   3.0s
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   1.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   1.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   3.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   3.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   3.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   4.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   1.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.9s
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   2.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.1s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   5.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   1.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.4s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   1.7s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.2s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   3.1s
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   7.2s
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   7.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   1.3s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   2.8s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   2.6s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   4.0s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   4.5s
# [CV] END estimator__alpha=0.0001, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   3.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   7.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  10.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  10.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  11.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  11.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.6s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.01, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   7.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  10.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  10.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  11.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  11.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   3.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   3.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   1.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   2.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   1.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.5s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.2s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.4s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   7.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  10.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  10.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  11.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  11.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.3s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   1.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   1.1s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   1.0s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.8s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.7s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.9s
# [CV] END estimator__alpha=0.001, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.7s
# ...
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.2s
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   9.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   8.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   9.7s
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  11.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  13.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   1.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   1.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   1.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   1.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   1.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   1.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   1.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=0.1, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   1.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=l1; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=constant, estimator__penalty=elasticnet; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l2; total time=   0.2s
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   9.7s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   8.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=   9.8s
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  11.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=l1; total time=  12.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=optimal, estimator__penalty=elasticnet; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l2; total time=   0.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   2.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   1.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.8s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=l1; total time=   0.9s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=invscaling, estimator__penalty=elasticnet; total time=   0.4s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.5s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l2; total time=   0.6s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.2s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=l1; total time=   2.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   2.3s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   2.0s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   2.1s
# [CV] END estimator__alpha=0.01, estimator__eta0=1.0, estimator__learning_rate=adaptive, estimator__penalty=elasticnet; total time=   2.1s
# Best parameters found: {'estimator__alpha': 0.001, 'estimator__eta0': 0.01, 'estimator__learning_rate': 'optimal', 'estimator__penalty': 'l2'}
# Best Logistic Regression Performance:
# Accuracy: 0.9863
# Precision: 1.0000
# Recall: 0.9729
# F1-Score: 0.9863
# Confusion Matrix:
# [[435   0]
#  [ 12 431]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       435
#            1       1.00      0.97      0.99       443
#
#     accuracy                           0.99       878
#    macro avg       0.99      0.99      0.99       878
# weighted avg       0.99      0.99      0.99       878
#
#
#  F1 Score:
# 0.9862700228832952

# %%
# Save the models as pickle file

joblib.dump(best_sgd_model, '../trained_models/sgd_model.pkl')
joblib.dump(best_sgd_model_pca, '../trained_models/sgd_model_pca.pkl')

# Also save best grid parameters as JSON for references
with open('../trained_models/params/sgd_model_params.json', 'w') as file:
    json.dump(grid_search.best_params_, file)

with open('../trained_models/params/sgd_model_pca_params.json', 'w') as file:
    json.dump(grid_search_pca.best_params_, file)
