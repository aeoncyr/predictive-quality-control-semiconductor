# %%
from sklearn.ensemble import RandomForestClassifier
import pickle
import joblib
import json
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, make_scorer, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
# Load data
with open('../dataset/secom_data_smoted.pkl', 'rb') as file:
    secom_data = pickle.load(file)
with open('../dataset/secom_pca_optimal.pkl', 'rb') as file:
    secom_data_pca = pickle.load(file)
with open('../dataset/secom_labels_smoted.pkl', 'rb') as file:
    secom_labels = pickle.load(file).squeeze()

print(secom_data.head())
print(secom_data_pca.head())
print(secom_labels)
# Out:
#        0        1          2          3       4      5         6       7    \
# 0  3031.79  2479.69  2186.9889   949.2201  1.2981  100.0  103.3322  0.1219
# 1  3049.97  2441.12  2263.3222  1383.8334  2.3986  100.0   85.1778  0.1196
# 2  2870.76  2583.56  2192.1889  1435.9611  2.3870  100.0  107.3989  0.1229
# 3  2996.90  2448.07  2162.7556  1041.1557  0.8479  100.0  107.2622  0.1221
# 4  2943.83  2445.17  2236.0667  1680.1825  1.4834  100.0   98.6889  0.1221
#
#       8       9    ...       580         581     582     583     584     585  \
# 0  1.4636  0.0009  ...  0.010500   70.061800  0.5035  0.0085  0.0024  1.6818
# 1  1.3792  0.0054  ...  0.003300   39.552800  0.5053  0.0159  0.0038  3.1456
# 2  1.4719 -0.0003  ...  0.006300  193.828600  0.5010  0.0127  0.0037  2.5344
# 3  1.4446 -0.0016  ...  0.005372   98.442837  0.5039  0.0169  0.0046  3.3497
# 4  1.4674  0.0161  ...  0.003900   49.945400  0.5001  0.0190  0.0043  3.7940
#
#       586     587     588       589
# 0  0.0484  0.0339  0.0105   70.0618
# 1  0.0262  0.0104  0.0033   39.5528
# 2  0.0111  0.0215  0.0063  193.8286
# 3  0.0270  0.0162  0.0051   59.9813
# 4  0.0263  0.0131  0.0039   49.9454
#
# [5 rows x 590 columns]
#        pca0      pca1      pca2      pca3      pca4      pca5      pca6  \
# 0 -0.745919 -0.107453  3.591643 -2.265534 -1.078268  0.432352  3.203903
# 1 -0.216757 -3.260718 -4.588245  3.149330 -2.764601  0.952743 -1.532329
# 2  0.074150 -3.289006 -1.796022  2.121194  5.671939 -3.015512 -4.380290
# 3 -2.068737 -1.618181  0.562073 -2.430326 -1.997398  1.386943 -1.210669
# 4  0.318059 -0.548636  2.378548 -2.263821  4.148559 -0.935855  0.080344
#
#        pca7      pca8      pca9  ...    pca148    pca149    pca150    pca151  \
# 0 -1.459077  0.586345 -0.128465  ... -1.399162 -0.970988  0.765390  1.085157
# 1 -1.837795  3.542800  3.169506  ... -0.266513 -0.403541  0.369211  1.928612
# 2 -2.632512 -1.438269  2.184061  ... -0.972266 -0.509511 -0.485179 -1.223665
# 3 -2.325825  1.248293  0.108320  ...  0.010721  0.197769  0.062963  0.165376
# 4  0.415713 -1.885009 -3.042244  ...  0.798716  0.080790  0.794015  0.541181
#
#      pca152    pca153    pca154    pca155    pca156    pca157
# 0 -0.852128  1.351813 -0.567651 -0.222668  0.987231 -0.015653
# 1 -0.215904  0.318676 -0.199971 -0.250996 -1.281222 -0.443229
# 2  1.529229  0.676787  0.489226 -0.150784 -0.168148  0.418307
# 3  0.579024  0.390517 -0.499806 -0.001619 -0.045170  0.329669
# 4  0.548210  0.787872  0.364292 -0.478866  0.988680  0.219400
#
# [5 rows x 158 columns]
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2921    0
# 2922    0
# 2923    0
# 2924    0
# 2925    0
# Name: Label, Length: 2926, dtype: int64

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(secom_data, secom_labels, test_size=0.3, random_state=42)

# Train-test split PCA
X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(secom_data_pca, secom_labels, test_size=0.3, random_state=42)

# %%
## Model definition

# Define Base RF
rf_model = RandomForestClassifier(random_state=42, class_weight='balanced')

# Wrap the SVC model with Bagging
bagging_rf = BaggingClassifier(estimator=rf_model, random_state=42)

# Use StratifiedKFold to maintain the proportion of classes in each fold
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Change evaluation metrics to F1-score
f1_scorer = make_scorer(f1_score, pos_label=0)

# Define grid parameters
param_grid = {
    'estimator__n_estimators': [100, 200, 500],              # Number of trees in the forest
    'estimator__max_features': ['sqrt', 'log2'],     # Number of features to consider at each split
    'estimator__max_depth': [None, 10, 20, 30],              # Maximum depth of the tree
    'estimator__min_samples_split': [2, 5, 10],              # Minimum number of samples required to split an internal node
    'estimator__min_samples_leaf': [1, 2, 4],                # Minimum number of samples required to be at a leaf node
}

# %%
# Train using the smoted data first

# Perform grid search with cross-validation
grid_search = GridSearchCV(estimator=bagging_rf, param_grid=param_grid, cv=stratified_kfold, scoring=f1_scorer, verbose=2)
grid_search.fit(X_train, y_train)

# Best parameters found
print(f"Best parameters found: {grid_search.best_params_}")

# Use the best found model
best_rf_model = grid_search.best_estimator_

# Predict and evaluate the model
rf_pred_best = best_rf_model.predict(X_test)
print("Best SVM Performance:")
print(f"Accuracy: {accuracy_score(y_test, rf_pred_best):.4f}")
print(f"Precision: {precision_score(y_test, rf_pred_best, pos_label=1):.4f}")
print(f"Recall: {recall_score(y_test, rf_pred_best, pos_label=1):.4f}")
print(f"F1-Score: {f1_score(y_test, rf_pred_best, pos_label=1):.4f}")

conf_matrix = confusion_matrix(y_test, rf_pred_best)
f1_score_smoted = f1_score(y_test, rf_pred_best)
report = classification_report(y_test, rf_pred_best)

print("Confusion Matrix:")
print(conf_matrix)

print("\nClassification Report:")
print(report)

print("\n F1 Score:")
print(f1_score_smoted)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  10.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  10.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  19.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  19.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  19.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  19.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  19.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  48.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  48.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  49.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  48.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  53.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   9.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   9.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   9.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  10.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   9.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  19.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  19.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  19.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  19.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  19.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  49.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  48.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  48.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  48.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  48.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  19.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  19.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  19.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  19.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  19.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  47.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  47.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  47.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  47.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  48.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  19.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  18.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  24.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  19.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  19.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  47.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  47.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  47.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  47.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  47.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   9.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   9.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  10.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  10.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  10.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  19.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  19.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  19.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  19.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  19.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  47.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  47.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  46.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  46.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  47.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  19.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  18.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  18.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  18.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  18.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  47.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  46.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  54.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  46.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  47.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   9.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  18.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  19.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  18.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  18.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  18.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  46.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  45.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  45.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  45.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  46.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   9.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   9.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   9.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   9.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   9.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  18.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  18.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  18.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  18.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  18.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  45.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  45.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  45.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  45.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  45.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   9.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  15.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  18.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  18.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  18.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  18.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  18.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  45.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  45.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  45.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  45.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  46.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  29.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  29.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  29.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  28.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  29.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  11.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  11.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  11.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  11.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  11.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  29.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  28.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  28.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  28.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  29.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  32.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  29.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  28.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  28.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  28.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  28.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  27.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  28.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  28.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  28.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  11.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  11.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  11.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  11.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  11.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  28.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  28.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  28.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  28.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  28.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   6.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  27.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  30.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  28.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  27.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  28.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  11.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  10.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  10.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  10.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  31.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  27.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  26.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  27.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  27.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  10.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  11.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  10.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  10.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  10.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  26.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  27.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  27.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  26.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  27.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   6.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  10.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  10.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  10.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  11.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  26.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  26.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  26.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  26.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  26.9s
# ...
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.2s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  10.3s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  10.4s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  10.4s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  10.7s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  10.5s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  25.6s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  25.7s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  25.6s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  25.6s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  26.2s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.1s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.2s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.3s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.3s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.4s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  10.2s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  10.3s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  10.3s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  10.4s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  10.4s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  25.5s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  25.5s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  25.8s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  25.5s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  25.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.1s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.1s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.2s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.2s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.2s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  10.2s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  10.1s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  10.2s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  10.2s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  10.3s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  25.5s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  25.7s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  25.6s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  25.7s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  26.2s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   4.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   4.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   4.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.0s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   5.0s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   9.8s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   9.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=   9.8s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  10.0s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  10.1s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  24.5s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  24.5s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  24.5s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  24.7s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  24.8s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   4.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   4.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   4.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   4.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   5.3s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   9.8s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  10.0s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   9.8s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=   9.8s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  13.5s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  24.5s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  30.1s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  25.4s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  25.0s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  24.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   4.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.0s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.0s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.0s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   5.1s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   9.8s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   9.8s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   9.8s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   9.8s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=   9.9s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  24.7s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  24.6s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  24.5s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  24.7s
# [CV] END estimator__max_depth=30, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  24.8s
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best parameters found: {'estimator__max_depth': None, 'estimator__max_features': 'sqrt', 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100}
# Best SVM Performance:
# Accuracy: 0.9989
# Precision: 1.0000
# Recall: 0.9977
# F1-Score: 0.9989
# Confusion Matrix:
# [[435   0]
#  [  1 442]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       435
#            1       1.00      1.00      1.00       443
#
#     accuracy                           1.00       878
#    macro avg       1.00      1.00      1.00       878
# weighted avg       1.00      1.00      1.00       878
#
#
#  F1 Score:
# 0.9988700564971752

# %%
# Now train using the PCA data

# Perform grid search with cross-validation
grid_search_pca = GridSearchCV(estimator=bagging_rf, param_grid=param_grid, cv=stratified_kfold, scoring=f1_scorer, verbose=2)
grid_search_pca.fit(X_train_pca, y_train_pca)

# Best parameters found
print(f"Best parameters found: {grid_search_pca.best_params_}")

# Use the best found model
best_rf_model_pca = grid_search_pca.best_estimator_

# Predict and evaluate the model
rf_pred_best_pca = best_rf_model_pca.predict(X_test_pca)
print("Best SVM Performance:")
print(f"Accuracy: {accuracy_score(y_test_pca, rf_pred_best_pca):.4f}")
print(f"Precision: {precision_score(y_test_pca, rf_pred_best_pca, pos_label=1):.4f}")
print(f"Recall: {recall_score(y_test_pca, rf_pred_best_pca, pos_label=1):.4f}")
print(f"F1-Score: {f1_score(y_test_pca, rf_pred_best_pca, pos_label=1):.4f}")

conf_matrix_pca = confusion_matrix(y_test_pca, rf_pred_best_pca)
f1_score_pca = f1_score(y_test_pca, rf_pred_best_pca)
report_pca = classification_report(y_test_pca, rf_pred_best_pca)

print("Confusion Matrix:")
print(conf_matrix_pca)

print("\nClassification Report:")
print(report_pca)

print("\n F1 Score:")
print(f1_score_pca)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  13.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  13.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  13.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  13.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  13.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  26.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  26.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  26.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  26.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  26.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  13.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  16.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  13.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  13.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  13.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  26.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  26.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  26.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  26.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  26.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  14.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  14.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  15.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  15.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  13.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  26.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  26.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  26.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  26.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  26.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.2min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  13.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  25.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  26.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  25.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  25.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  26.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  13.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  25.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  27.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  26.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  28.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  26.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  12.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  12.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  12.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  12.8s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  12.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  25.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  25.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  25.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  25.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  25.7s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  24.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  27.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  25.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  24.6s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  24.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  24.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  24.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  24.4s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  24.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  24.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  12.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  12.1s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  12.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  15.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  12.5s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  24.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  24.3s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  24.0s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  23.9s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  24.2s
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  17.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  17.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  17.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  17.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  17.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  43.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  43.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  43.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  43.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  44.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  17.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  17.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  17.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  20.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  18.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  43.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  43.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  43.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  43.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  43.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  17.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  17.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  17.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  17.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  17.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  43.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  43.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  43.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  42.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  43.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  17.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  17.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  16.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  16.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  17.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  43.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  42.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  42.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  42.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  45.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  16.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  16.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  16.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  19.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  17.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  42.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  43.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  42.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  42.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  43.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  17.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  17.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  16.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  17.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  17.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  42.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  42.6s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  42.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  42.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  42.7s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   7.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   7.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=   8.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  16.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  16.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  16.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  15.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  16.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  40.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  42.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  41.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  40.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time=  40.5s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   7.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   7.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   7.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=   8.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  16.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  16.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  15.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  15.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  16.2s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  40.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  40.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  39.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  40.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time=  40.4s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   7.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   7.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100; total time=   8.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  15.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  16.0s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  15.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  15.9s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  16.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  40.3s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  40.1s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  39.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  39.8s
# [CV] END estimator__max_depth=None, estimator__max_features=log2, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=500; total time=  40.4s
# ...
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.5min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.2min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  13.7s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  14.1s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  15.5s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  15.2s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  15.0s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  27.3s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  28.8s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  28.7s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  28.2s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  29.3s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.2min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.2min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.2min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.2min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.2min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  13.7s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  14.1s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  14.7s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  14.8s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  14.3s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  28.3s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  28.5s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  28.1s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  28.2s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  28.7s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.2min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.2min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  14.9s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  14.1s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  13.8s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  13.7s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  13.6s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  26.8s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  27.1s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  26.8s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  26.8s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  27.1s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  13.0s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  13.1s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  12.9s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  13.7s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100; total time=  13.1s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  26.4s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  26.4s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  26.0s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  26.0s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200; total time=  26.6s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.2s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.4s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  12.3s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  13.5s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100; total time=  27.5s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  31.5s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  25.6s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  24.9s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  24.5s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200; total time=  24.9s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=500; total time= 1.0min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.3s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.3s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.2s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.2s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100; total time=  12.4s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  24.6s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  24.7s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  31.8s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  30.4s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200; total time=  26.2s
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.1min
# [CV] END estimator__max_depth=30, estimator__max_features=sqrt, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=500; total time= 1.4min

# %%
# Save the models as pickle file

joblib.dump(best_rf_model, '../trained_models/rf_model.pkl')
joblib.dump(best_rf_model_pca, '../trained_models/rf_model_pca.pkl')

# Also save best grid parameters as JSON for references
with open('../trained_models/params/rf_model_params.json', 'w') as file:
    json.dump(grid_search.best_params_, file)

with open('../trained_models/params/rf_model_pca_params.json', 'w') as file:
    json.dump(grid_search_pca.best_params_, file)
# Out:
# Random Forest Performance:
# Accuracy: 0.9331
# Precision: 0.0000
# Recall: 0.0000
# F1-Score: 0.0000
# d:\fajar\Projects\predictive-quality-control-semiconductor\.conda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Let's try using the unprocessed data

secom_data_raw = pd.read_csv('../dataset/secom.data', sep='\s+', header=None)
secom_labels_raw = pd.read_csv('../dataset/secom_labels.data', sep='\s+', header=None, usecols=[0], names=['Label'])

secom_labels_raw = secom_labels_raw.replace(1, 0)  # Change 1 to 0, fail = 0
secom_labels_raw = secom_labels_raw.replace(-1, 1)  # Change -1 to 1, pass = 1

# Fill the NaN with mean using the imputer
imputer = SimpleImputer()
secom_data_raw_filled = imputer.fit_transform(secom_data_raw)

# Let's check if our models are saved successfuly
rf_model = joblib.load('../trained_models/rf_model.pkl')

new_prediction = rf_model.predict(secom_data_raw_filled)

print("Best SVM Performance:")
print(f"Accuracy: {accuracy_score(secom_labels_raw, new_prediction):.4f}")
print(f"Precision: {precision_score(secom_labels_raw, new_prediction, pos_label=1):.4f}")
print(f"Recall: {recall_score(secom_labels_raw, new_prediction, pos_label=1):.4f}")
print(f"F1-Score: {f1_score(secom_labels_raw, new_prediction, pos_label=1):.4f}")

conf_matrix_new = confusion_matrix(secom_labels_raw, new_prediction)
f1_score_new = f1_score(secom_labels_raw, new_prediction)
report_new = classification_report(secom_labels_raw, new_prediction)

print("Confusion Matrix:")
print(conf_matrix_new)

print("\nClassification Report:")
print(report_new)

print("\n F1 Score:")
print(f1_score_new)
